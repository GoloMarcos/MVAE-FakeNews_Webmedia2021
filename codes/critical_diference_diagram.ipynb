# %%
# !pip install orange3

# %%
import Orange

names = ["BoW-TFIDF",'BoW-TF','Bow-Binary',"DistilBERT", "Density", "LIWK", "AE", "VAE", 'MVAE-FakeNews', 'MVAE-LIWK']

avranks =  [10,8.0833,5.75,7.1667,6.1667,5.75,4.9167,3.25,1.2083,2.7083]

cd = Orange.evaluation.scoring.compute_CD(avranks, 12) # tested on 12 datasets

Orange.evaluation.scoring.graph_ranks(avranks, names, cd=cd,filename="todas.pdf", width=7, textspace=1.4)
print(cd)
# Out:
# 3.910418082408125
